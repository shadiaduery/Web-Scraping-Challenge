# %% [markdown]
# ## Let's Scrape Job Listings!
# We will scrape job listings from Monster.com, specifically Data Scientist roles in the Portland, OR area. We are interested in the job title, the company, and the location.
#
# This notebook will take us step by step through scraping and eventually loading into MongoDB for further use. Please follow along and read the comments and text carefully!

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo
from pprint import pprint

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection.
# If these don't exist, they will be created. Otherwise we will point to them.
# `monster_db` is the mongo database, `jobs` is the mongo collection 
db = client.monster_db
collection = db.jobs

# %%
# You can also see existing collections like this. 
# But note that the collection doesn't display until data is inserted.
names = db.list_collection_names()

for name in names:
    print(name)

# %%
# URL of page to be scraped
url = "https://www.monster.com/jobs/search/?q=Data-Scientist&where=Portland__2C-OR"

# %%
# Use the requests library to grab the HTML from the site. Then use beautiful soup
# to parse it and create the soup object.

# Minimize the number of times this code gets run! Once the data is in memory, we don't need
# to run this repeatedly. You only need to rerun it if you change the URL or if you restart 
# the jupyter notebook.
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# #### Step 1
# Navigate to the page in a web browser and observe what it looks like. Also, right-click -> view page source to have the HTML open and available to you.
#
# We want to scrape all the job listings on the left hand panel and store them in the mongoDB. Imagine that we are building a "job aggregator"-aggregator - so we want to scrape jobs from all different listing places, like monster.com, linkedin, indeed, etc and have them all in one location. This activity will take us only through monster.com scraping.

# %% [markdown]
# <img src="../images/listings.png" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# #### Step 2
# We'll want to identify a bit of text that we assume is relatively unique, so we can locate it in the HTML. `Data Scientist` would be way too common. I chose `Lead Engineer - Analytics Architecture`. The added benefit of this is that the company, Eclaro, should be relatively uncommon in the text also.

# %% [markdown]
# <img src="../images/html.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# When I search for `Lead Engineer - Analytics Architecture` in the HTML, I see that it appears twice, both in the same row - line 1199. (It's all the way over to the right, so I had to scroll way left). I also notice that I can see the other information I'm interested nearby in the HTML: the company name, Eclaro, and the location, Happy Valley.

# %% [markdown]
# #### Step 3
# Identify an HTML element where all the information I'm interested in is nested within it. For example, it looks like `<div class="summary">` has job title, company info, and location all nested under it. I might also be able to use `<div class="flex-row>` or `<section class="card-content">`. This might take a bit of experimentation to find the correct "level" of nesting. However, note that I can't choose something like `<div class="company">` because the job title and locations are not nested within it.

# %% [markdown]
# #### Step 4
# Let's start writing code! I'm going to choose the "smallest" HTML container that I think will hold all the information I'm interested in. This is because it will take less navigating through an HTML hierarchy to grab the data I'm interested in.

# %%
# grab all HTML containers that hold the job listing information
# use `find_all()` along with the class name to filter correctly
results = soup.find_all("div", class_="summary")

# %%
# What type of data structure is the `results` variable?
results
# Out:
# [<div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xconwaycx" data-m_impr_j_jawsid="459374640" data-m_impr_j_jobid="222108792" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="45.5303" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6848" data-m_impr_j_occid="11892" data-m_impr_j_p="1" data-m_impr_j_postingid="ff3d7caf-47a3-4a7d-924f-5198583832aa" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="d97a4a1f-bd38-486f-82f7-4c355b26c7c8" href="https://job-openings.monster.com/senior-data-scientist-portland-or-us-xpo-logistics/222108792" onclick="clickJobTitle('plid=578&amp;pcid=11&amp;poccid=11892','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xconwaycx_XPO Logistics&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-12-01T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Senior Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">XPO Logistics</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="xw250306941wx" data-m_impr_j_jawsid="461979398" data-m_impr_j_jobid="222494076" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="45.5234" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6763" data-m_impr_j_occid="11970" data-m_impr_j_p="2" data-m_impr_j_postingid="cf40354d-e699-414b-8161-cf5b8c10f48d" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="674221d1-e092-4c2d-81b8-b0fa7acc95ac" href="https://job-openings.monster.com/software-dev-engineer-iii-or-iv-doe-portland-or-us-cambia-health-solutions-inc/222494076" onclick="clickJobTitle('plid=578&amp;pcid=660&amp;poccid=11970','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Software Dev Engineer III or IV, DOE&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xw250306941wx_Cambia Health Solutions, Inc.&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-12-03T12:00&quot;,&quot;eVar53&quot;:&quot;1500127001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Software Dev Engineer III or IV, DOE
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Cambia Health Solutions, Inc.</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xjobot2018x" data-m_impr_j_jawsid="462016414" data-m_impr_j_jobid="222509587" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="45.413" data-m_impr_j_lid="578" data-m_impr_j_long="-122.7254" data-m_impr_j_occid="11892" data-m_impr_j_p="3" data-m_impr_j_postingid="226943a5-c916-4997-b331-048b6bdaec32" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="1b66f70a-258c-49b0-8f39-ce06c92ca489" href="https://job-openings.monster.com/enterprise-account-executive-portland-or-us-jobot/222509587" onclick="clickJobTitle('plid=578&amp;pcid=11&amp;poccid=11892','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Enterprise Account Executive&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xjobot2018x_Jobot&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-12-04T12:00&quot;,&quot;eVar53&quot;:&quot;4100683001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Enterprise Account Executive
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Jobot</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="660" data-m_impr_j_coc="xapexppvx" data-m_impr_j_jawsid="459979570" data-m_impr_j_jobid="222207993" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="45.5184" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6743" data-m_impr_j_occid="11904" data-m_impr_j_p="4" data-m_impr_j_postingid="11eea45d-fe99-46aa-b800-d8c48ae5a341" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="73c10697-70f7-4d7f-aefd-496bc71ce847" href="https://job-openings.monster.com/bi-analyst-portland-or-us-apex-systems/222207993" onclick="clickJobTitle('plid=578&amp;pcid=660&amp;poccid=11904','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;BI Analyst&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xapexppvx_Apex Systems&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-12-03T12:00&quot;,&quot;eVar53&quot;:&quot;1500144001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">BI Analyst
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Apex Systems</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xndix" data-m_impr_j_jawsid="460960920" data-m_impr_j_jobid="222321860" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="45.5136" data-m_impr_j_lid="578" data-m_impr_j_long="-122.5646" data-m_impr_j_occid="11892" data-m_impr_j_p="5" data-m_impr_j_postingid="1f94f2b6-5ac4-4446-836a-7abb92f0c717" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="df5155d3-4f4c-4732-9aa0-f4701d913693" href="https://job-openings.monster.com/lead-engineer-analytics-architecture-happy-valley-or-us-eclaro/222321860" onclick="clickJobTitle('plid=578&amp;pcid=11&amp;poccid=11892','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Lead Engineer - Analytics Architecture&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xndix_Eclaro&quot;,&quot;eVar31&quot;:&quot;Happy Valley_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-11-25T12:00&quot;,&quot;eVar53&quot;:&quot;1700190001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Lead Engineer - Analytics Architecture
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Eclaro</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Happy Valley, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="462176535" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.6387" data-m_impr_j_lid="697" data-m_impr_j_long="-122.6615" data-m_impr_j_occid="11866" data-m_impr_j_p="6" data-m_impr_j_postingid="f8d4f43e-2668-47b5-b98f-c9c65a0d3e16" data-m_impr_j_pvc="9dab78a3-0e85-40d3-b7e1-a15165e443bf" data-m_impr_s_t="t" data-m_impr_uuid="8be296e0-5bb0-42df-a47c-7602af408e96" href="https://job-openings.monster.com/healthcare-quality-data-scientist-vancouver-wa-us-peacehealth/f8d4f43e-2668-47b5-b98f-c9c65a0d3e16" onclick="clickJobTitle('plid=697&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Healthcare Quality Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_PeaceHealth&quot;,&quot;eVar31&quot;:&quot;Vancouver_WA_&quot;,&quot;prop24&quot;:&quot;2020-12-05T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Healthcare Quality Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">PeaceHealth</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Vancouver, WA
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="459950323" data-m_impr_j_jobid="507070" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.487" data-m_impr_j_lid="578" data-m_impr_j_long="-122.8038" data-m_impr_j_occid="11866" data-m_impr_j_p="7" data-m_impr_j_postingid="93f39ea2-cccf-4677-8ddf-ad532d3101ce" data-m_impr_j_pvc="6e32555b-a19f-44ac-857c-221390cd3378" data-m_impr_s_t="t" data-m_impr_uuid="fbb3e759-adee-4c06-a799-11211bb6809f" href="https://job-openings.monster.com/senior-data-scientist-supply-chain-advanced-analytics-beaverton-or-us-nike/93f39ea2-cccf-4677-8ddf-ad532d3101ce" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Data Scientist, Supply Chain Advanced Analytics&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Nike&quot;,&quot;eVar31&quot;:&quot;Beaverton_OR_&quot;,&quot;prop24&quot;:&quot;2020-11-19T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Senior Data Scientist, Supply Chain Advanced Analytics
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Nike</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Beaverton, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="458344529" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.5234" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6763" data-m_impr_j_occid="11866" data-m_impr_j_p="8" data-m_impr_j_postingid="d30a6a8e-29c0-468e-b794-117a0c3a480d" data-m_impr_j_pvc="975f7bce-fbdd-41e3-b520-db0b66c146ab" data-m_impr_s_t="t" data-m_impr_uuid="6e9b23e3-a5fc-447c-bad9-b791ea77755d" href="https://job-openings.monster.com/principal-data-scientist-clinical-data-management-portland-or-us-premier-research-group/d30a6a8e-29c0-468e-b794-117a0c3a480d" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Principal Data Scientist (Clinical Data Management)&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Premier Research Group&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop24&quot;:&quot;2020-11-11T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Principal Data Scientist (Clinical Data Management)
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Premier Research Group</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="456924636" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.5234" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6763" data-m_impr_j_occid="11866" data-m_impr_j_p="9" data-m_impr_j_postingid="75e95d9b-cefd-4b08-8158-0271b35029e6" data-m_impr_j_pvc="f9a95ea9-b4ff-4100-a265-28f72130e8f7" data-m_impr_s_t="t" data-m_impr_uuid="e3913bf2-0faf-4c90-a314-77d4ef544f28" href="https://job-openings.monster.com/data-scientist-portland-or-us-comscore/75e95d9b-cefd-4b08-8158-0271b35029e6" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_comScore&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop24&quot;:&quot;2020-11-04T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">comScore</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="454425590" data-m_impr_j_jobid="27419507" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.5234" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6763" data-m_impr_j_occid="11866" data-m_impr_j_p="10" data-m_impr_j_postingid="5afa7b42-17cc-4a49-a3ed-cba17baa57a1" data-m_impr_j_pvc="554b7b84-9d13-4463-a09e-a84bde4eaeb2" data-m_impr_s_t="t" data-m_impr_uuid="57fd7bc4-bdd3-4010-9418-4c2286573ad8" href="https://job-openings.monster.com/data-scientist-portland-or-portland-or-us-conexess-group-llc/5afa7b42-17cc-4a49-a3ed-cba17baa57a1" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Scientist - Portland, OR&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Conexess Group, LLC&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop24&quot;:&quot;2020-10-22T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Data Scientist - Portland, OR
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Conexess Group, LLC</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="452579580" data-m_impr_j_jobid="27418605" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.5234" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6763" data-m_impr_j_occid="11866" data-m_impr_j_p="11" data-m_impr_j_postingid="cb542297-dccc-4ebd-a71d-5b9bbc588df3" data-m_impr_j_pvc="d348ff15-3955-4bdc-9911-2ebd6517cf69" data-m_impr_s_t="t" data-m_impr_uuid="b01873a6-48fa-4827-a84e-f2c9cfef56b3" href="https://job-openings.monster.com/marketing-data-scientist-portland-or-portland-or-us-moda-health/cb542297-dccc-4ebd-a71d-5b9bbc588df3" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Marketing Data Scientist - Portland, OR&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Moda Health&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop24&quot;:&quot;2020-10-13T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Marketing Data Scientist - Portland, OR
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Moda Health</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="434300697" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.487" data-m_impr_j_lid="578" data-m_impr_j_long="-122.8509" data-m_impr_j_occid="11866" data-m_impr_j_p="12" data-m_impr_j_postingid="79caf760-84df-480f-8b33-5e94d3ca7d04" data-m_impr_j_pvc="equestftpin" data-m_impr_s_t="t" data-m_impr_uuid="e3326b76-d8ec-41e6-8dd1-f4e992798f83" href="https://job-openings.monster.com/data-scientist-i-beaverton-or-us-dat/79caf760-84df-480f-8b33-5e94d3ca7d04" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Scientist I&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_DAT&quot;,&quot;eVar31&quot;:&quot;Beaverton_OR_&quot;,&quot;prop24&quot;:&quot;2020-06-04T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Data Scientist I
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">DAT</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Beaverton, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="462076803" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.5178" data-m_impr_j_lid="578" data-m_impr_j_long="-122.8593" data-m_impr_j_occid="11866" data-m_impr_j_p="13" data-m_impr_j_postingid="738afa23-f92f-48a5-84eb-c4d7ebb30c33" data-m_impr_j_pvc="bc00081a-4581-471b-8b16-2162e602b3c9" data-m_impr_s_t="t" data-m_impr_uuid="3207a3c4-50b2-481c-86b0-428a53fe9c6c" href="https://job-openings.monster.com/data-scientist-beaverton-or-us-biztek-people-inc/738afa23-f92f-48a5-84eb-c4d7ebb30c33" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_BizTek People, Inc.&quot;,&quot;eVar31&quot;:&quot;Beaverton_OR_&quot;,&quot;prop24&quot;:&quot;2020-12-04T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">BizTek People, Inc.</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Beaverton, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="460703834" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.4923" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6915" data-m_impr_j_occid="11866" data-m_impr_j_p="14" data-m_impr_j_postingid="862f79d3-439d-4ca8-b4ff-f61720c90777" data-m_impr_j_pvc="jobdiva" data-m_impr_s_t="t" data-m_impr_uuid="d943b744-52c4-4786-886d-bc3e5021c0db" href="https://job-openings.monster.com/senior-data-scientist-portland-or-us-apr-staffing/862f79d3-439d-4ca8-b4ff-f61720c90777" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_APR Staffing&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop24&quot;:&quot;2020-11-24T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Senior Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">APR Staffing</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="462013130" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.3689" data-m_impr_j_lid="578" data-m_impr_j_long="-122.7641" data-m_impr_j_occid="11866" data-m_impr_j_p="15" data-m_impr_j_postingid="548b0d16-fb16-4cb1-89ae-4d0a9090622d" data-m_impr_j_pvc="equestftpin" data-m_impr_s_t="t" data-m_impr_uuid="d4d18d1e-77c7-4794-b171-c13fa1fa88e8" href="https://job-openings.monster.com/data-scientist-3-tualatin-or-us-lam-research-corporation/548b0d16-fb16-4cb1-89ae-4d0a9090622d" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Scientist 3&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Lam Research Corporation&quot;,&quot;eVar31&quot;:&quot;Tualatin_OR_&quot;,&quot;prop24&quot;:&quot;2020-12-04T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Data Scientist 3
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Lam Research Corporation</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Tualatin, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="558" data-m_impr_j_coc="" data-m_impr_j_jawsid="461760360" data-m_impr_j_jobid="696069000" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.3689" data-m_impr_j_lid="578" data-m_impr_j_long="-122.7641" data-m_impr_j_occid="15442" data-m_impr_j_p="16" data-m_impr_j_postingid="d7fae554-ff0f-466d-8efb-b8c9725e5eca" data-m_impr_j_pvc="3e4caba3-12c1-4904-878c-5294243977f2" data-m_impr_s_t="t" data-m_impr_uuid="a1391eb5-15ee-44a7-a452-b9ee7c298277" href="https://job-openings.monster.com/data-scientist-3-tualatin-or-us-97062-tualatin-or-us-lam-research/d7fae554-ff0f-466d-8efb-b8c9725e5eca" onclick="clickJobTitle('plid=578&amp;pcid=558&amp;poccid=15442','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Data Scientist 3 (Tualatin, OR, US, 97062)&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_LAM Research&quot;,&quot;eVar31&quot;:&quot;Tualatin_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-12-02T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Data Scientist 3 (Tualatin, OR, US, 97062)
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">LAM Research</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Tualatin, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xconwaycx" data-m_impr_j_jawsid="458161591" data-m_impr_j_jobid="221942187" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="45.5303" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6848" data-m_impr_j_occid="11892" data-m_impr_j_p="17" data-m_impr_j_postingid="c921309a-bb73-4bc4-96d8-88955ce7227d" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="c2bd0131-832e-47b5-beda-587b401f5669" href="https://job-openings.monster.com/associate-graduate-program-it-ltl-july-2021-portland-or-us-xpo-logistics/221942187" onclick="clickJobTitle('plid=578&amp;pcid=11&amp;poccid=11892','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Associate, Graduate Program, IT LTL - July 2021&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xconwaycx_XPO Logistics&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-11-25T12:00&quot;,&quot;eVar53&quot;:&quot;1500136001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">Associate, Graduate Program, IT LTL - July 2021
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">XPO Logistics</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Portland, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xwashnlxx" data-m_impr_j_jawsid="462253878" data-m_impr_j_jobid="222552449" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.641" data-m_impr_j_lid="697" data-m_impr_j_long="-122.6257" data-m_impr_j_occid="11892" data-m_impr_j_p="18" data-m_impr_j_postingid="d2d92a1c-c143-48d1-bdeb-b41dbff76149" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="993a60dd-e9cb-4d8a-96c9-1dc46b10545d" href="https://job-openings.monster.com/healthcare-quality-data-scientist-vancouver-wa-us-peacehealth/d2d92a1c-c143-48d1-bdeb-b41dbff76149" onclick="clickJobTitle('plid=697&amp;pcid=11&amp;poccid=11892','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Healthcare Quality Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xwashnlxx_PeaceHealth&quot;,&quot;eVar31&quot;:&quot;Vancouver_WA_&quot;,&quot;prop24&quot;:&quot;2020-12-05T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Healthcare Quality Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">PeaceHealth</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Vancouver, WA
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="457773925" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.487" data-m_impr_j_lid="578" data-m_impr_j_long="-122.8038" data-m_impr_j_occid="11866" data-m_impr_j_p="19" data-m_impr_j_postingid="899654dd-7cbb-4201-8788-9d1e0c1746b4" data-m_impr_j_pvc="fd5d0c38-fa9a-4f8c-8b14-952b1e69d38d" data-m_impr_s_t="t" data-m_impr_uuid="2083f601-628f-4b79-a4a7-e6de9711b657" href="https://job-openings.monster.com/principal-data-scientist-beaverton-or-us-nike/899654dd-7cbb-4201-8788-9d1e0c1746b4" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Principal Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Nike&quot;,&quot;eVar31&quot;:&quot;Beaverton_OR_&quot;,&quot;prop24&quot;:&quot;2020-11-09T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Principal Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Nike</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Beaverton, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="457635301" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.3689" data-m_impr_j_lid="578" data-m_impr_j_long="-122.7641" data-m_impr_j_occid="11866" data-m_impr_j_p="20" data-m_impr_j_postingid="30e5ae52-3d3b-4df0-813f-0fb0d0e318a0" data-m_impr_j_pvc="equestftpin" data-m_impr_s_t="t" data-m_impr_uuid="adef9b38-e3df-4949-854b-bad5749aa916" href="https://job-openings.monster.com/new-college-graduate-data-scientist-3-151803-tualatin-or-us-lam-research-corporation/30e5ae52-3d3b-4df0-813f-0fb0d0e318a0" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;New College Graduate - Data Scientist 3 - 151803&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Lam Research Corporation&quot;,&quot;eVar31&quot;:&quot;Tualatin_OR_&quot;,&quot;prop24&quot;:&quot;2020-11-08T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">New College Graduate - Data Scientist 3 - 151803
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Lam Research Corporation</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Tualatin, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="457615764" data-m_impr_j_jobid="504953" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.487" data-m_impr_j_lid="578" data-m_impr_j_long="-122.8038" data-m_impr_j_occid="11866" data-m_impr_j_p="21" data-m_impr_j_postingid="bde9000e-d63a-4d84-88bc-165104343242" data-m_impr_j_pvc="6e32555b-a19f-44ac-857c-221390cd3378" data-m_impr_s_t="t" data-m_impr_uuid="a5b7e8e8-57c9-4506-9ae4-4a05f1870dbe" href="https://job-openings.monster.com/principal-data-scientist-beaverton-or-us-nike/bde9000e-d63a-4d84-88bc-165104343242" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Principal Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Nike&quot;,&quot;eVar31&quot;:&quot;Beaverton_OR_&quot;,&quot;prop24&quot;:&quot;2020-11-07T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Principal Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Nike</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Beaverton, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="453160022" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.487" data-m_impr_j_lid="578" data-m_impr_j_long="-122.8038" data-m_impr_j_occid="11866" data-m_impr_j_p="22" data-m_impr_j_postingid="bdeb8934-8e43-4c5b-ad8f-92addded7b75" data-m_impr_j_pvc="fd5d0c38-fa9a-4f8c-8b14-952b1e69d38d" data-m_impr_s_t="t" data-m_impr_uuid="85806329-8fad-4425-9441-379cc50f3ee3" href="https://job-openings.monster.com/principal-data-scientist-beaverton-or-us-nike/bdeb8934-8e43-4c5b-ad8f-92addded7b75" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Principal Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Nike&quot;,&quot;eVar31&quot;:&quot;Beaverton_OR_&quot;,&quot;prop24&quot;:&quot;2020-10-16T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Principal Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Nike</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Beaverton, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="453291478" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.487" data-m_impr_j_lid="578" data-m_impr_j_long="-122.8038" data-m_impr_j_occid="11866" data-m_impr_j_p="23" data-m_impr_j_postingid="970d6755-b073-4b4f-a76b-319b141d9ba8" data-m_impr_j_pvc="6e32555b-a19f-44ac-857c-221390cd3378" data-m_impr_s_t="t" data-m_impr_uuid="4187aac1-a946-42df-8576-e4c5c7729263" href="https://job-openings.monster.com/principal-data-scientist-beaverton-or-us-nike/970d6755-b073-4b4f-a76b-319b141d9ba8" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Principal Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Nike&quot;,&quot;eVar31&quot;:&quot;Beaverton_OR_&quot;,&quot;prop24&quot;:&quot;2020-10-16T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Principal Data Scientist
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Nike</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Beaverton, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="452339441" data-m_impr_j_jobid="0" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.487" data-m_impr_j_lid="578" data-m_impr_j_long="-122.8038" data-m_impr_j_occid="11866" data-m_impr_j_p="24" data-m_impr_j_postingid="4270ab56-36f1-439a-b14c-7540b449d51b" data-m_impr_j_pvc="fd5d0c38-fa9a-4f8c-8b14-952b1e69d38d" data-m_impr_s_t="t" data-m_impr_uuid="14976b6a-a871-47f1-bae4-9fdaf334d171" href="https://job-openings.monster.com/senior-data-scientist-commercial-analytics-beaverton-or-us-nike/4270ab56-36f1-439a-b14c-7540b449d51b" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Data Scientist, Commercial Analytics&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Nike&quot;,&quot;eVar31&quot;:&quot;Beaverton_OR_&quot;,&quot;prop24&quot;:&quot;2020-10-12T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Senior Data Scientist, Commercial Analytics
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Nike</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Beaverton, OR
#  </span>
#  </div>
#  </div>,
#  <div class="summary">
#  <header class="card-header">
#  <h2 class="title"><a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="559" data-m_impr_j_coc="" data-m_impr_j_jawsid="452189962" data-m_impr_j_jobid="502724" data-m_impr_j_jpm="2" data-m_impr_j_jpt="3" data-m_impr_j_lat="45.487" data-m_impr_j_lid="578" data-m_impr_j_long="-122.8038" data-m_impr_j_occid="11866" data-m_impr_j_p="25" data-m_impr_j_postingid="a5877928-fcc3-47df-baec-6894a5f24675" data-m_impr_j_pvc="6e32555b-a19f-44ac-857c-221390cd3378" data-m_impr_s_t="t" data-m_impr_uuid="958db03c-5791-44f6-af5d-897042f6ff15" href="https://job-openings.monster.com/senior-data-scientist-commercial-analytics-beaverton-or-us-nike/a5877928-fcc3-47df-baec-6894a5f24675" onclick="clickJobTitle('plid=578&amp;pcid=559&amp;poccid=11866','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Data Scientist, Commercial Analytics&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;_Nike&quot;,&quot;eVar31&quot;:&quot;Beaverton_OR_&quot;,&quot;prop24&quot;:&quot;2020-10-10T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Aggregated&quot;,&quot;eVar74&quot;:&quot;regular&quot;}')">Senior Data Scientist, Commercial Analytics
#  </a></h2>
#  </header>
#  <div class="company">
#  <span class="name">Nike</span>
#  <ul class="list-inline">
#  </ul>
#  </div>
#  <div class="location">
#  <span class="name">
#  Beaverton, OR
#  </span>
#  </div>
#  </div>]

# %%
# As we explore the HTML, it's easier to operate on one element of the results list, rather 
# than immediately need to loop through the entire list and parse through every element.
# So let's slice off the first element and just work with that for now.
# Once we've identified everything, we'll go back and put it into the loop.
result = results[0]

# Now, the `result` variable is still a soup object, so we can apply the BeautifulSoup methods.
# For example, we can pretty print the single element
print(result.prettify())
# Out:
# <div class="summary">
#  <header class="card-header">
#   <h2 class="title">
#    <a data-bypass="true" data-m_impr_a_placement_id="JSR2CW" data-m_impr_j_cid="11" data-m_impr_j_coc="xconwaycx" data-m_impr_j_jawsid="459374640" data-m_impr_j_jobid="222108792" data-m_impr_j_jpm="1" data-m_impr_j_jpt="1" data-m_impr_j_lat="45.5303" data-m_impr_j_lid="578" data-m_impr_j_long="-122.6848" data-m_impr_j_occid="11892" data-m_impr_j_p="1" data-m_impr_j_postingid="ff3d7caf-47a3-4a7d-924f-5198583832aa" data-m_impr_j_pvc="monster" data-m_impr_s_t="t" data-m_impr_uuid="d97a4a1f-bd38-486f-82f7-4c355b26c7c8" href="https://job-openings.monster.com/senior-data-scientist-portland-or-us-xpo-logistics/222108792" onclick="clickJobTitle('plid=578&amp;pcid=11&amp;poccid=11892','Data Scientist',''); clickJobTitleSiteCat('{&quot;events.event48&quot;:&quot;true&quot;,&quot;eVar25&quot;:&quot;Senior Data Scientist&quot;,&quot;eVar66&quot;:&quot;Monster&quot;,&quot;eVar67&quot;:&quot;JSR2CW&quot;,&quot;eVar26&quot;:&quot;xconwaycx_XPO Logistics&quot;,&quot;eVar31&quot;:&quot;Portland_OR_&quot;,&quot;prop22&quot;:&quot;Employee&quot;,&quot;prop24&quot;:&quot;2020-12-01T12:00&quot;,&quot;eVar53&quot;:&quot;1500152001001&quot;,&quot;eVar50&quot;:&quot;Duration&quot;,&quot;eVar74&quot;:&quot;logo&quot;}')">
#     Senior Data Scientist
#    </a>
#   </h2>
#  </header>
#  <div class="company">
#   <span class="name">
#    XPO Logistics
#   </span>
#   <ul class="list-inline">
#   </ul>
#  </div>
#  <div class="location">
#   <span class="name">
#    Portland, OR
#   </span>
#  </div>
# </div>

# %% [markdown]
# #### Step 5
# Note that this is NOT the same job we were examining before. This is because we just took the first element out of the results, rather than finding the specific job we were working with before. So I will go back to the actual webpage and confirm this information still makes sense. I see that there appears to be a `Senior Data Scientist` role at `XPO logistics`.
#
# Yep.

# %% [markdown]
# <img src="../images/data-scientist.png" alt="Drawing" style="width: 600px;"/>

# %% [markdown]
# #### Step 6
# Let's write code to extract all the relevant pieces of data

# %%
# Within our results soup object, identify HTML elements that hold the job title,
# the company, and the location.
# Select them with the `find()` method and a class name, then use `.text` to grab the
# HTML content from the elements, then use `strip()` to clean out any extra characters.

title = result.find("h2", class_="title").text.strip()
company = result.find("div", class_="company").text.strip()
location = result.find("div", class_="location").text.strip()

# %%
# Print out these values to ensure they look correct
print(title, company, location)
# Out:
# Senior Data Scientist XPO Logistics Portland, OR

# %% [markdown]
# #### Step 7
# Let's put this all into a loop! So instead of just extracting from the single `result` variable we sliced off, we're going to go through the entire `results` iterable and apply the
# parsing we just identified.

# %%
# for each element in our `results` iterable
for result in results:
    # We need to handle this in a try/except block because it will kick us out of the
    # loop if we have an error
    try:
        # get the title for each job listing
        title = result.find("h2", class_="title").text.strip()
        
        # get the company for each job listing
        company = result.find("div", class_="company").text.strip()
        
        # get the location for each job listing
        location = result.find("div", class_="location").text.strip()
        
        # print these out and make sure they look ok
        print(title, company, location)
        
    # handle an error here. Basically, do nothing
    except:
        print("Error")
# Out:
# Senior Data Scientist XPO Logistics Portland, OR
# Software Dev Engineer III or IV, DOE Cambia Health Solutions, Inc. Portland, OR
# Enterprise Account Executive Jobot Portland, OR
# BI Analyst Apex Systems Portland, OR
# Lead Engineer - Analytics Architecture Eclaro Happy Valley, OR
# Healthcare Quality Data Scientist PeaceHealth Vancouver, WA
# Senior Data Scientist, Supply Chain Advanced Analytics Nike Beaverton, OR
# Principal Data Scientist (Clinical Data Management) Premier Research Group Portland, OR
# Data Scientist comScore Portland, OR
# Data Scientist - Portland, OR Conexess Group, LLC Portland, OR
# Marketing Data Scientist - Portland, OR Moda Health Portland, OR
# Data Scientist I DAT Beaverton, OR
# Data Scientist BizTek People, Inc. Beaverton, OR
# Senior Data Scientist APR Staffing Portland, OR
# Data Scientist 3 Lam Research Corporation Tualatin, OR
# Data Scientist 3 (Tualatin, OR, US, 97062) LAM Research Tualatin, OR
# Associate, Graduate Program, IT LTL - July 2021 XPO Logistics Portland, OR
# Healthcare Quality Data Scientist PeaceHealth Vancouver, WA
# Principal Data Scientist Nike Beaverton, OR
# New College Graduate - Data Scientist 3 - 151803 Lam Research Corporation Tualatin, OR
# Principal Data Scientist Nike Beaverton, OR
# Principal Data Scientist Nike Beaverton, OR
# Principal Data Scientist Nike Beaverton, OR
# Senior Data Scientist, Commercial Analytics Nike Beaverton, OR
# Senior Data Scientist, Commercial Analytics Nike Beaverton, OR

# %% [markdown]
# #### Step 8
# Great, it looks like it's working! Now the last step is to store this information in MongoDB. We'll copy and paste the last bit of code and change the `print()` section to insert the data instead.

# %%
# for each element in our `results` iterable
for result in results:
    # We need to handle this in a try/except block because it will kick us out of the
    # loop if we have an error
    try:
        # get the title for each job listing
        title = result.find("h2", class_="title").text.strip()
        
        # get the company for each job listing
        company = result.find("div", class_="company").text.strip()
        
        # get the location for each job listing
        location = result.find("div", class_="location").text.strip()
        
        # Package this data up and insert into mongo DB
        # What data structure do we need to use to insert into mongo DB?
        post = {
            "title": title,
            "company": company,
            "location": location
        }
        
        # finally, insert that using the `collections` variable we created way up at the top
        collection.insert_one(post)
        
    # handle an error here. Basically, do nothing except print an error message.
    except:
        print("Error")

# %%
# Finally, display everything out of the mongo DB
listings = collection.find()

for listing in listings:
    pprint(listing)
# Out:
# {'_id': ObjectId('5fcfc420c830ee94de5b4cc9'),
#  'company': 'XPO Logistics',
#  'location': 'Portland, OR',
#  'title': 'Senior Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cca'),
#  'company': 'Cambia Health Solutions, Inc.',
#  'location': 'Portland, OR',
#  'title': 'Software Dev Engineer III or IV, DOE'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4ccb'),
#  'company': 'Jobot',
#  'location': 'Portland, OR',
#  'title': 'Enterprise Account Executive'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4ccc'),
#  'company': 'Apex Systems',
#  'location': 'Portland, OR',
#  'title': 'BI Analyst'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4ccd'),
#  'company': 'Eclaro',
#  'location': 'Happy Valley, OR',
#  'title': 'Lead Engineer - Analytics Architecture'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cce'),
#  'company': 'PeaceHealth',
#  'location': 'Vancouver, WA',
#  'title': 'Healthcare Quality Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4ccf'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Senior Data Scientist, Supply Chain Advanced Analytics'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd0'),
#  'company': 'Premier Research Group',
#  'location': 'Portland, OR',
#  'title': 'Principal Data Scientist (Clinical Data Management)'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd1'),
#  'company': 'comScore',
#  'location': 'Portland, OR',
#  'title': 'Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd2'),
#  'company': 'Conexess Group, LLC',
#  'location': 'Portland, OR',
#  'title': 'Data Scientist - Portland, OR'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd3'),
#  'company': 'Moda Health',
#  'location': 'Portland, OR',
#  'title': 'Marketing Data Scientist - Portland, OR'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd4'),
#  'company': 'DAT',
#  'location': 'Beaverton, OR',
#  'title': 'Data Scientist I'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd5'),
#  'company': 'BizTek People, Inc.',
#  'location': 'Beaverton, OR',
#  'title': 'Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd6'),
#  'company': 'APR Staffing',
#  'location': 'Portland, OR',
#  'title': 'Senior Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd7'),
#  'company': 'Lam Research Corporation',
#  'location': 'Tualatin, OR',
#  'title': 'Data Scientist 3'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd8'),
#  'company': 'LAM Research',
#  'location': 'Tualatin, OR',
#  'title': 'Data Scientist 3 (Tualatin, OR, US, 97062)'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cd9'),
#  'company': 'XPO Logistics',
#  'location': 'Portland, OR',
#  'title': 'Associate, Graduate Program, IT LTL - July 2021'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cda'),
#  'company': 'PeaceHealth',
#  'location': 'Vancouver, WA',
#  'title': 'Healthcare Quality Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cdb'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Principal Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cdc'),
#  'company': 'Lam Research Corporation',
#  'location': 'Tualatin, OR',
#  'title': 'New College Graduate - Data Scientist 3 - 151803'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cdd'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Principal Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cde'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Principal Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4cdf'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Principal Data Scientist'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4ce0'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Senior Data Scientist, Commercial Analytics'}
# {'_id': ObjectId('5fcfc420c830ee94de5b4ce1'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Senior Data Scientist, Commercial Analytics'}

# %% [markdown]
# #### Step 9 / Bonus
# Now that we've implemented the solution, it never fails that the requirements shift underneath us. In this case, a salesperson has come back to us and said that they also want to capture the link to the company's logo that monster displays. Note that not every job listing has an image!

# %%
# clear out the data from your mongo DB
collection.drop()

# %%
# Now, we need to identify where this data is stored. Is it nested under the same HTML 
# element as the other data we've already captured?

# No, we need to update our `results` iterable to capture the relevant info
results = soup.find_all("div", class_="flex-row")

# for each element in our `results` iterable
for result in results:
    # We need to handle this in a try/except block because it will kick us out of the
    # loop if we have an error
    try:
        # accessing title, company, and location should still work the same way
        title = result.find("h2", class_="title").text.strip()
        company = result.find("div", class_="company").text.strip()
        location = result.find("div", class_="location").text.strip()
        
        # Package this data up
        post = {
            "title": title,
            "company": company,
            "location": location
        }
        
        # but the image link is stored somewhere else, and it's stored as an attribute.
        # how do we access attributes?
        # The image link is stored in an `img` tag that's nested in a `div`
        img_container = result.find("div", class_="mux-company-logo")
        
        # now we need to access this nested img class and access the attribute inside,
        # but only if it exists!
        if img_container.img:
            img_link = img_container.img["src"]
            # and remember to add it to the data structure that we insert into mongo!
            post["img_link"] = img_link  
        
        # finally, insert that using the `collections` variable we created way up at the top
        collection.insert_one(post)
        
    # handle an error here. Basically, do nothing except print an error message.
    except:
        print("Error")

# %%
# Finally, display everything out of the mongo DB, this time with the images, if they exist
listings = collection.find()

for listing in listings:
    pprint(listing)
# Out:
# {'_id': ObjectId('5fcfc78dc830ee94de5b4ce2'),
#  'company': 'XPO Logistics',
#  'img_link': 'https://media.newjobs.com/clu/xcon/xconwaycx/branding/12271/XPO-Logistics-logo.png',
#  'location': 'Portland, OR',
#  'title': 'Senior Data Scientist'}
# {'_id': ObjectId('5fcfc78dc830ee94de5b4ce3'),
#  'company': 'Cambia Health Solutions, Inc.',
#  'img_link': 'https://media.newjobs.com/clu/xw25/xw250306941wx/branding/95885/Cambia-Health-Solutions-Inc-logo.jpg',
#  'location': 'Portland, OR',
#  'title': 'Software Dev Engineer III or IV, DOE'}
# {'_id': ObjectId('5fcfc78dc830ee94de5b4ce4'),
#  'company': 'Jobot',
#  'img_link': 'https://media.newjobs.com/clu/xjob/xjobot2018x/branding/161229/Jobot-logo-637293157573438943.png',
#  'location': 'Portland, OR',
#  'title': 'Enterprise Account Executive'}
# {'_id': ObjectId('5fcfc78dc830ee94de5b4ce5'),
#  'company': 'Apex Systems',
#  'img_link': 'https://media.newjobs.com/clu/xape/xapexppvx/branding/27017/Apex-Systems-logo-637363659369052192.png',
#  'location': 'Portland, OR',
#  'title': 'BI Analyst'}
# {'_id': ObjectId('5fcfc78dc830ee94de5b4ce6'),
#  'company': 'Eclaro',
#  'img_link': 'https://media.newjobs.com/clu/xndi/xndix/branding/11067/Eclaro-International-Inc-logo.png',
#  'location': 'Happy Valley, OR',
#  'title': 'Lead Engineer - Analytics Architecture'}
# {'_id': ObjectId('5fcfc78dc830ee94de5b4ce7'),
#  'company': 'comScore',
#  'img_link': 'https://coda.newjobs.com/api/imagesproxy/ms/mm/xcsnx/cp/comscoreLogo.png',
#  'location': 'Portland, OR',
#  'title': 'Data Scientist'}
# {'_id': ObjectId('5fcfc78dc830ee94de5b4ce8'),
#  'company': 'XPO Logistics',
#  'img_link': 'https://media.newjobs.com/clu/xcon/xconwaycx/branding/12271/XPO-Logistics-logo.png',
#  'location': 'Portland, OR',
#  'title': 'Associate, Graduate Program, IT LTL - July 2021'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4ce9'),
#  'company': 'XPO Logistics',
#  'img_link': 'https://media.newjobs.com/clu/xcon/xconwaycx/branding/12271/XPO-Logistics-logo.png',
#  'location': 'Portland, OR',
#  'title': 'Senior Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cea'),
#  'company': 'Cambia Health Solutions, Inc.',
#  'img_link': 'https://media.newjobs.com/clu/xw25/xw250306941wx/branding/95885/Cambia-Health-Solutions-Inc-logo.jpg',
#  'location': 'Portland, OR',
#  'title': 'Software Dev Engineer III or IV, DOE'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4ceb'),
#  'company': 'Jobot',
#  'img_link': 'https://media.newjobs.com/clu/xjob/xjobot2018x/branding/161229/Jobot-logo-637293157573438943.png',
#  'location': 'Portland, OR',
#  'title': 'Enterprise Account Executive'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cec'),
#  'company': 'Apex Systems',
#  'img_link': 'https://media.newjobs.com/clu/xape/xapexppvx/branding/27017/Apex-Systems-logo-637363659369052192.png',
#  'location': 'Portland, OR',
#  'title': 'BI Analyst'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4ced'),
#  'company': 'Eclaro',
#  'img_link': 'https://media.newjobs.com/clu/xndi/xndix/branding/11067/Eclaro-International-Inc-logo.png',
#  'location': 'Happy Valley, OR',
#  'title': 'Lead Engineer - Analytics Architecture'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cee'),
#  'company': 'PeaceHealth',
#  'location': 'Vancouver, WA',
#  'title': 'Healthcare Quality Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cef'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Senior Data Scientist, Supply Chain Advanced Analytics'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf0'),
#  'company': 'Premier Research Group',
#  'location': 'Portland, OR',
#  'title': 'Principal Data Scientist (Clinical Data Management)'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf1'),
#  'company': 'comScore',
#  'img_link': 'https://coda.newjobs.com/api/imagesproxy/ms/mm/xcsnx/cp/comscoreLogo.png',
#  'location': 'Portland, OR',
#  'title': 'Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf2'),
#  'company': 'Conexess Group, LLC',
#  'location': 'Portland, OR',
#  'title': 'Data Scientist - Portland, OR'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf3'),
#  'company': 'Moda Health',
#  'location': 'Portland, OR',
#  'title': 'Marketing Data Scientist - Portland, OR'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf4'),
#  'company': 'DAT',
#  'location': 'Beaverton, OR',
#  'title': 'Data Scientist I'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf5'),
#  'company': 'BizTek People, Inc.',
#  'location': 'Beaverton, OR',
#  'title': 'Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf6'),
#  'company': 'APR Staffing',
#  'location': 'Portland, OR',
#  'title': 'Senior Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf7'),
#  'company': 'Lam Research Corporation',
#  'location': 'Tualatin, OR',
#  'title': 'Data Scientist 3'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf8'),
#  'company': 'LAM Research',
#  'location': 'Tualatin, OR',
#  'title': 'Data Scientist 3 (Tualatin, OR, US, 97062)'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cf9'),
#  'company': 'XPO Logistics',
#  'img_link': 'https://media.newjobs.com/clu/xcon/xconwaycx/branding/12271/XPO-Logistics-logo.png',
#  'location': 'Portland, OR',
#  'title': 'Associate, Graduate Program, IT LTL - July 2021'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cfa'),
#  'company': 'PeaceHealth',
#  'location': 'Vancouver, WA',
#  'title': 'Healthcare Quality Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cfb'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Principal Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cfc'),
#  'company': 'Lam Research Corporation',
#  'location': 'Tualatin, OR',
#  'title': 'New College Graduate - Data Scientist 3 - 151803'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cfd'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Principal Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cfe'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Principal Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4cff'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Principal Data Scientist'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4d00'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Senior Data Scientist, Commercial Analytics'}
# {'_id': ObjectId('5fcfc891c830ee94de5b4d01'),
#  'company': 'Nike',
#  'location': 'Beaverton, OR',
#  'title': 'Senior Data Scientist, Commercial Analytics'}
